# %% [markdown]
# # Lab 4- Object Oriented Programming
#
# For all of the exercises below, make sure you provide tests of your solutions.

# %% [markdown]
# 1. Write a "counter" class that can be incremented up to a specified maximum value, will print an error if an attempt is made to increment beyond that value, and allows reseting the counter.

# %%
class Counter:
    def __init__(self, maximum):
        self.maximum = maximum
        self.value = 0

    def increment(self):
        if self.value >= self.maximum:
            print("Error")
        else:
            self.value += 1
        return self.value

    def reset(self):
        self.value = 0
        return self.value

    def __str__(self):
        return str(self.value)


c = Counter(3)
print(c.increment())
print(c.increment())
print(c.increment())
print(c.increment())
print(c)
print(c.reset())
print(c.increment())
print(c)
# Out:
# 1
# 2
# 3
# Error
# 3
# 3
# 0
# 1
# 1

# %% [markdown]
# 2. Copy and paste your solution to question 1 and modify it so that all the data held by the counter is private. Implement functions to check the value of the counter, check the maximum value, and check if the counter is at the maximum.

# %%
class Counter:
    def __init__(self, maximum):
        self.__maximum = maximum
        self.__value = 0

    def increment(self):
        if self.__value >= self.__maximum:
            print("Error")
        else:
            self.__value += 1
        return self.__value

    def reset(self):
        self.__value = 0
        return self.__value

    def get_value(self):
        return self.__value

    def get_maximum(self):
        return self.__maximum

    def is_at_maximum(self):
        return self.__value == self.__maximum


c = Counter(2)
print(c.increment())
print(c.increment())
print(c.increment())
print(c.get_value())
print(c.get_maximum())
print(c.is_at_maximum())
print(c.reset())
print(c.is_at_maximum())
# Out:
# 1
# 2
# Error
# 2
# 2
# 2
# True
# 0
# False

# %% [markdown]
# 3. Implement a class to represent a rectangle, holding the length, width, and $x$ and $y$ coordinates of a corner of the object. Implement functions that compute the area and perimeter of the rectangle. Make all data members private and privide accessors to retrieve values of data members.

# %%
class Rectangle:
    def __init__(self, length, width, x, y):
        self.__length = length
        self.__width = width
        self.__x = x
        self.__y = y

    def area(self):
        return self.__length * self.__width

    def perimeter(self):
        return 2 * (self.__length + self.__width)

    def get_length(self):
        return self.__length

    def get_width(self):
        return self.__width

    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y


r = Rectangle(5, 3, 0, 0)
print(r.get_length())
print(r.get_width())
print(r.get_x())
print(r.get_y())
print(r.area())
print(r.perimeter())
# Out:
# 5
# 3
# 0
# 0
# 15
# 16

# %% [markdown]
# 4. Implement a class to represent a circle, holding the radius and $x$ and $y$ coordinates of center of the object. Implement functions that compute the area and perimeter of the rectangle. Make all data members private and privide accessors to retrieve values of data members.

# %%
import math

class Circle:
    def __init__(self, radius, x, y):
        self.__radius = radius
        self.__x = x
        self.__y = y

    def area(self):
        return math.pi * self.__radius ** 2

    def perimeter(self):
        return 2 * math.pi * self.__radius

    def get_radius(self):
        return self.__radius

    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y


c = Circle(4, 1, 2)
print(c.get_radius())
print(c.get_x())
print(c.get_y())
print(c.area())
print(c.perimeter())
# Out:
# 4
# 1
# 2
# 50.26548245743669
# 25.132741228718345

# %% [markdown]
# 5. Implement a common base class for the classes implemented in 3 and 4 above which implements all common methods as not implemented functions (virtual). Re-implement your regtangle and circule classes to inherit from the base class and overload the functions accordingly.

# %%
import math

class Shape:
    def area(self):
        raise NotImplementedError

    def perimeter(self):
        raise NotImplementedError

    def get_x(self):
        raise NotImplementedError

    def get_y(self):
        raise NotImplementedError


class Rectangle(Shape):
    def __init__(self, length, width, x, y):
        self.__length = length
        self.__width = width
        self.__x = x
        self.__y = y

    def area(self):
        return self.__length * self.__width

    def perimeter(self):
        return 2 * (self.__length + self.__width)

    def get_length(self):
        return self.__length

    def get_width(self):
        return self.__width

    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y


class Circle(Shape):
    def __init__(self, radius, x, y):
        self.__radius = radius
        self.__x = x
        self.__y = y

    def area(self):
        return math.pi * self.__radius ** 2

    def perimeter(self):
        return 2 * math.pi * self.__radius

    def get_radius(self):
        return self.__radius

    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y


shapes = [
    Rectangle(5, 3, 0, 0),
    Circle(4, 1, 2)
]

for s in shapes:
    print(s.get_x(), s.get_y())
    print(s.area())
    print(s.perimeter())
# Out:
# 0 0
# 15
# 16
# 1 2
# 50.26548245743669
# 25.132741228718345

# %% [markdown]
# 6. Implement a triangle class analogous to the rectangle and circle in question 5.

# %%
import math

class Shape:
    def area(self):
        raise NotImplementedError

    def perimeter(self):
        raise NotImplementedError

    def get_x(self):
        raise NotImplementedError

    def get_y(self):
        raise NotImplementedError


class Rectangle(Shape):
    def __init__(self, length, width, x, y):
        self.__length = length
        self.__width = width
        self.__x = x
        self.__y = y

    def area(self):
        return self.__length * self.__width

    def perimeter(self):
        return 2 * (self.__length + self.__width)

    def get_length(self):
        return self.__length

    def get_width(self):
        return self.__width

    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y


class Circle(Shape):
    def __init__(self, radius, x, y):
        self.__radius = radius
        self.__x = x
        self.__y = y

    def area(self):
        return math.pi * self.__radius ** 2

    def perimeter(self):
        return 2 * math.pi * self.__radius

    def get_radius(self):
        return self.__radius

    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y


class Triangle(Shape):
    def __init__(self, a, b, c, x, y):
        self.__a = a
        self.__b = b
        self.__c = c
        self.__x = x
        self.__y = y

    def area(self):
        s = (self.__a + self.__b + self.__c) / 2
        return math.sqrt(s * (s - self.__a) * (s - self.__b) * (s - self.__c))

    def perimeter(self):
        return self.__a + self.__b + self.__c

    def get_sides(self):
        return self.__a, self.__b, self.__c

    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y


shapes = [
    Rectangle(5, 3, 0, 0),
    Circle(4, 1, 2),
    Triangle(3, 4, 5, 2, 2)
]

for s in shapes:
    print(s.get_x(), s.get_y())
    print(s.area())
    print(s.perimeter())
# Out:
# 0 0
# 15
# 16
# 1 2
# 50.26548245743669
# 25.132741228718345
# 2 2
# 6.0
# 12

# %% [markdown]
# 7. Add a function to the object classes, including the base, that returns a list of up to 16 pairs of  $x$ and $y$ points on the parameter of the object.

# %%
import math

class Shape:
    def area(self):
        raise NotImplementedError

    def perimeter(self):
        raise NotImplementedError

    def get_x(self):
        raise NotImplementedError

    def get_y(self):
        raise NotImplementedError

    def boundary_points(self, n=16):
        raise NotImplementedError


class Rectangle(Shape):
    def __init__(self, length, width, x, y):
        self.__length = length
        self.__width = width
        self.__x = x
        self.__y = y

    def area(self):
        return self.__length * self.__width

    def perimeter(self):
        return 2 * (self.__length + self.__width)

    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y

    def boundary_points(self, n=16):
        pts = []
        for i in range(n):
            t = i / n
            if t < 0.25:
                x = self.__x + t * 4 * self.__length
                y = self.__y
            elif t < 0.5:
                x = self.__x + self.__length
                y = self.__y + (t - 0.25) * 4 * self.__width
            elif t < 0.75:
                x = self.__x + self.__length - (t - 0.5) * 4 * self.__length
                y = self.__y + self.__width
            else:
                x = self.__x
                y = self.__y + self.__width - (t - 0.75) * 4 * self.__width
            pts.append((x, y))
        return pts


class Circle(Shape):
    def __init__(self, radius, x, y):
        self.__radius = radius
        self.__x = x
        self.__y = y

    def area(self):
        return math.pi * self.__radius ** 2

    def perimeter(self):
        return 2 * math.pi * self.__radius

    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y

    def boundary_points(self, n=16):
        pts = []
        for i in range(n):
            theta = 2 * math.pi * i / n
            x = self.__x + self.__radius * math.cos(theta)
            y = self.__y + self.__radius * math.sin(theta)
            pts.append((x, y))
        return pts


class Triangle(Shape):
    def __init__(self, a, b, c, x, y):
        self.__a = a
        self.__b = b
        self.__c = c
        self.__x = x
        self.__y = y

    def area(self):
        s = (self.__a + self.__b + self.__c) / 2
        return math.sqrt(s * (s - self.__a) * (s - self.__b) * (s - self.__c))

    def perimeter(self):
        return self.__a + self.__b + self.__c

    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y

    def boundary_points(self, n=16):
        p1 = (self.__x, self.__y)
        p2 = (self.__x + self.__a, self.__y)
        cosC = (self.__a**2 + self.__b**2 - self.__c**2) / (2 * self.__a * self.__b)
        sinC = math.sqrt(1 - cosC**2)
        p3 = (self.__x + self.__b * cosC, self.__y + self.__b * sinC)
        verts = [p1, p2, p3]
        pts = []
        for i in range(n):
            t = i / n * 3
            edge = int(t)
            local = t - edge
            x = verts[edge][0] + local * (verts[(edge + 1) % 3][0] - verts[edge][0])
            y = verts[edge][1] + local * (verts[(edge + 1) % 3][1] - verts[edge][1])
            pts.append((x, y))
        return pts


shapes = [
    Rectangle(5, 3, 0, 0),
    Circle(4, 1, 2),
    Triangle(3, 4, 5, 2, 2)
]

for s in shapes:
    print(s.boundary_points())

# %% [markdown]
# 8. Add a function to the object classes, including the base, that tests if a given set of $x$ and $y$ coordinates are inside of the object. You'll have to think through how to determine if a set of coordinates are inside an object for each object type.

# %%
import math

class Shape:
    def area(self):
        raise NotImplementedError

    def perimeter(self):
        raise NotImplementedError

    def get_x(self):
        raise NotImplementedError

    def get_y(self):
        raise NotImplementedError

    def boundary_points(self, n=16):
        raise NotImplementedError

    def contains(self, x, y):
        raise NotImplementedError


class Rectangle(Shape):
    def __init__(self, length, width, x, y):
        self.__length = length
        self.__width = width
        self.__x = x
        self.__y = y

    def area(self):
        return self.__length * self.__width

    def perimeter(self):
        return 2 * (self.__length + self.__width)

    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y

    def boundary_points(self, n=16):
        pts = []
        for i in range(n):
            t = i / n
            if t < 0.25:
                px = self.__x + t * 4 * self.__length
                py = self.__y
            elif t < 0.5:
                px = self.__x + self.__length
                py = self.__y + (t - 0.25) * 4 * self.__width
            elif t < 0.75:
                px = self.__x + self.__length - (t - 0.5) * 4 * self.__length
                py = self.__y + self.__width
            else:
                px = self.__x
                py = self.__y + self.__width - (t - 0.75) * 4 * self.__width
            pts.append((px, py))
        return pts

    def contains(self, x, y):
        return self.__x <= x <= self.__x + self.__length and self.__y <= y <= self.__y + self.__width


class Circle(Shape):
    def __init__(self, radius, x, y):
        self.__radius = radius
        self.__x = x
        self.__y = y

    def area(self):
        return math.pi * self.__radius ** 2

    def perimeter(self):
        return 2 * math.pi * self.__radius

    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y

    def boundary_points(self, n=16):
        pts = []
        for i in range(n):
            theta = 2 * math.pi * i / n
            px = self.__x + self.__radius * math.cos(theta)
            py = self.__y + self.__radius * math.sin(theta)
            pts.append((px, py))
        return pts

    def contains(self, x, y):
        return (x - self.__x) ** 2 + (y - self.__y) ** 2 <= self.__radius ** 2


class Triangle(Shape):
    def __init__(self, a, b, c, x, y):
        self.__a = a
        self.__b = b
        self.__c = c
        self.__x = x
        self.__y = y
        self.__p1 = (x, y)
        self.__p2 = (x + a, y)
        cosC = (a*a + b*b - c*c) / (2*a*b)
        sinC = math.sqrt(1 - cosC*cosC)
        self.__p3 = (x + b*cosC, y + b*sinC)

    def area(self):
        s = (self.__a + self.__b + self.__c) / 2
        return math.sqrt(s * (s - self.__a) * (s - self.__b) * (s - self.__c))

    def perimeter(self):
        return self.__a + self.__b + self.__c

    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y

    def boundary_points(self, n=16):
        verts = [self.__p1, self.__p2, self.__p3]
        pts = []
        for i in range(n):
            t = i / n * 3
            edge = int(t)
            local = t - edge
            x = verts[edge][0] + local * (verts[(edge + 1) % 3][0] - verts[edge][0])
            y = verts[edge][1] + local * (verts[(edge + 1) % 3][1] - verts[edge][1])
            pts.append((x, y))
        return pts

    def contains(self, x, y):
        def area(x1,y1,x2,y2,x3,y3):
            return abs((x1*(y2-y3)+x2*(y3-y1)+x3*(y1-y2))/2)
        A = area(*self.__p1, *self.__p2, *self.__p3)
        A1 = area(x,y, *self.__p2, *self.__p3)
        A2 = area(*self.__p1, x,y, *self.__p3)
        A3 = area(*self.__p1, *self.__p2, x,y)
        return abs(A - (A1 + A2 + A3)) < 1e-6


shapes = [
    Rectangle(5, 3, 0, 0),
    Circle(4, 1, 2),
    Triangle(3, 4, 5, 2, 2)
]

tests = [(1,1), (10,10), (3,2), (2,2)]

for s in shapes:
    for t in tests:
        print(type(s).__name__, t, s.contains(t[0], t[1]))

# %% [markdown]
# 9. Add a function in the base class of the object classes that returns true/false testing that the object overlaps with another object.

# %%
import math

class Shape:
    def area(self):
        raise NotImplementedError

    def perimeter(self):
        raise NotImplementedError

    def get_x(self):
        raise NotImplementedError

    def get_y(self):
        raise NotImplementedError

    def boundary_points(self, n=16):
        raise NotImplementedError

    def contains(self, x, y):
        raise NotImplementedError

    def overlaps(self, other):
        for p in self.boundary_points():
            if other.contains(p[0], p[1]):
                return True
        for p in other.boundary_points():
            if self.contains(p[0], p[1]):
                return True
        return False


class Rectangle(Shape):
    def __init__(self, length, width, x, y):
        self.__length = length
        self.__width = width
        self.__x = x
        self.__y = y

    def area(self):
        return self.__length * self.__width

    def perimeter(self):
        return 2 * (self.__length + self.__width)

    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y

    def boundary_points(self, n=16):
        pts = []
        for i in range(n):
            t = i / n
            if t < 0.25:
                px = self.__x + t * 4 * self.__length
                py = self.__y
            elif t < 0.5:
                px = self.__x + self.__length
                py = self.__y + (t - 0.25) * 4 * self.__width
            elif t < 0.75:
                px = self.__x + self.__length - (t - 0.5) * 4 * self.__length
                py = self.__y + self.__width
            else:
                px = self.__x
                py = self.__y + self.__width - (t - 0.75) * 4 * self.__width
            pts.append((px, py))
        return pts

    def contains(self, x, y):
        return self.__x <= x <= self.__x + self.__length and self.__y <= y <= self.__y + self.__width


class Circle(Shape):
    def __init__(self, radius, x, y):
        self.__radius = radius
        self.__x = x
        self.__y = y

    def area(self):
        return math.pi * self.__radius ** 2

    def perimeter(self):
        return 2 * math.pi * self.__radius

    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y

    def boundary_points(self, n=16):
        pts = []
        for i in range(n):
            theta = 2 * math.pi * i / n
            px = self.__x + self.__radius * math.cos(theta)
            py = self.__y + self.__radius * math.sin(theta)
            pts.append((px, py))
        return pts

    def contains(self, x, y):
        return (x - self.__x) ** 2 + (y - self.__y) ** 2 <= self.__radius ** 2


class Triangle(Shape):
    def __init__(self, a, b, c, x, y):
        self.__a = a
        self.__b = b
        self.__c = c
        self.__x = x
        self.__y = y
        self.__p1 = (x, y)
        self.__p2 = (x + a, y)
        cosC = (a*a + b*b - c*c) / (2*a*b)
        sinC = math.sqrt(1 - cosC*cosC)
        self.__p3 = (x + b*cosC, y + b*sinC)

    def area(self):
        s = (self.__a + self.__b + self.__c) / 2
        return math.sqrt(s * (s - self.__a) * (s - self.__b) * (s - self.__c))

    def perimeter(self):
        return self.__a + self.__b + self.__c

    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y

    def boundary_points(self, n=16):
        verts = [self.__p1, self.__p2, self.__p3]
        pts = []
        for i in range(n):
            t = i / n * 3
            edge = int(t)
            local = t - edge
            x = verts[edge][0] + local * (verts[(edge + 1) % 3][0] - verts[edge][0])
            y = verts[edge][1] + local * (verts[(edge + 1) % 3][1] - verts[edge][1])
            pts.append((x, y))
        return pts

    def contains(self, x, y):
        def area(x1,y1,x2,y2,x3,y3):
            return abs((x1*(y2-y3)+x2*(y3-y1)+x3*(y1-y2))/2)
        A = area(*self.__p1, *self.__p2, *self.__p3)
        A1 = area(x,y, *self.__p2, *self.__p3)
        A2 = area(*self.__p1, x,y, *self.__p3)
        A3 = area(*self.__p1, *self.__p2, x,y)
        return abs(A - (A1 + A2 + A3)) < 1e-6


r = Rectangle(5, 3, 0, 0)
c = Circle(2, 3, 1)
t = Triangle(3, 4, 5, 6, 6)

print(r.overlaps(c))
print(r.overlaps(t))
print(c.overlaps(t))

# %% [markdown]
# 10. Copy the `Canvas` class from lecture to in a python file creating a `paint` module. Copy your classes from above into the module and implement paint functions. Implement a `CompoundShape` class. Create a simple drawing demonstrating that all of your classes are working.

# %%
from tkinter import Tk, Canvas as TkCanvas
import math

class Canvas:
    def **init**(self, width=400, height=400):
self.root = Tk()
self.canvas = TkCanvas(self.root, width=width, height=height)
self.canvas.pack()

```
def draw_polygon(self, points, color="black"):
    flat = []
    for p in points:
        flat.extend(p)
    self.canvas.create_polygon(flat, outline=color, fill="")

def draw_oval(self, x0, y0, x1, y1, color="black"):
    self.canvas.create_oval(x0, y0, x1, y1, outline=color)

def show(self):
    self.root.mainloop()
```

class Shape:
def area(self):
raise NotImplementedError

```
def perimeter(self):
    raise NotImplementedError

def contains(self, x, y):
    raise NotImplementedError

def boundary_points(self, n=32):
    raise NotImplementedError

def paint(self, canvas):
    raise NotImplementedError

def overlaps(self, other):
    for p in self.boundary_points():
        if other.contains(p[0], p[1]):
            return True
    for p in other.boundary_points():
        if self.contains(p[0], p[1]):
            return True
    return False
```

class Rectangle(Shape):
def **init**(self, length, width, x, y):
self.__length = length
self.__width = width
self.__x = x
self.__y = y

```
def area(self):
    return self.__length * self.__width

def perimeter(self):
    return 2 * (self.__length + self.__width)

def contains(self, x, y):
    return self.__x <= x <= self.__x + self.__length and self.__y <= y <= self.__y + self.__width

def boundary_points(self, n=32):
    pts = []
    for i in range(n):
        t = i / n
        if t < 0.25:
            px = self.__x + t * 4 * self.__length
            py = self.__y
        elif t < 0.5:
            px = self.__x + self.__length
            py = self.__y + (t - 0.25) * 4 * self.__width
        elif t < 0.75:
            px = self.__x + self.__length - (t - 0.5) * 4 * self.__length
            py = self.__y + self.__width
        else:
            px = self.__x
            py = self.__y + self.__width - (t - 0.75) * 4 * self.__width
        pts.append((px, py))
    return pts

def paint(self, canvas):
    pts = [
        (self.__x, self.__y),
        (self.__x + self.__length, self.__y),
        (self.__x + self.__length, self.__y + self.__width),
        (self.__x, self.__y + self.__width)
    ]
    canvas.draw_polygon(pts)
```

class Circle(Shape):
def **init**(self, radius, x, y):
self.__radius = radius
self.__x = x
self.__y = y

```
def area(self):
    return math.pi * self.__radius ** 2

def perimeter(self):
    return 2 * math.pi * self.__radius

def contains(self, x, y):
    return (x - self.__x) ** 2 + (y - self.__y) ** 2 <= self.__radius ** 2

def boundary_points(self, n=32):
    pts = []
    for i in range(n):
        t = 2 * math.pi * i / n
        pts.append((self.__x + self.__radius * math.cos(t),
                    self.__y + self.__radius * math.sin(t)))
    return pts

def paint(self, canvas):
    canvas.draw_oval(self.__x - self.__radius,
                     self.__y - self.__radius,
                     self.__x + self.__radius,
                     self.__y + self.__radius)
```

class Triangle(Shape):
def **init**(self, a, b, c, x, y):
self.__a = a
self.__b = b
self.__c = c
self.__p1 = (x, y)
self.__p2 = (x + a, y)
cosC = (a*a + b*b - c*c) / (2*a*b)
sinC = math.sqrt(1 - cosC*cosC)
self.__p3 = (x + b*cosC, y + b*sinC)

```
def area(self):
    s = (self.__a + self.__b + self.__c) / 2
    return math.sqrt(s*(s-self.__a)*(s-self.__b)*(s-self.__c))

def perimeter(self):
    return self.__a + self.__b + self.__c

def contains(self, x, y):
    def A(x1,y1,x2,y2,x3,y3):
        return abs((x1*(y2-y3)+x2*(y3-y1)+x3*(y1-y2))/2)
    a = A(*self.__p1,*self.__p2,*self.__p3)
    a1 = A(x,y,*self.__p2,*self.__p3)
    a2 = A(*self.__p1,x,y,*self.__p3)
    a3 = A(*self.__p1,*self.__p2,x,y)
    return abs(a-(a1+a2+a3)) < 1e-6

def boundary_points(self, n=32):
    verts = [self.__p1, self.__p2, self.__p3]
    pts = []
    for i in range(n):
        t = i / n * 3
        e = int(t)
        l = t - e
        x = verts[e][0] + l*(verts[(e+1)%3][0]-verts[e][0])
        y = verts[e][1] + l*(verts[(e+1)%3][1]-verts[e][1])
        pts.append((x,y))
    return pts

def paint(self, canvas):
    canvas.draw_polygon([self.__p1, self.__p2, self.__p3])
```

class CompoundShape(Shape):
def **init**(self):
self.__shapes = []

```
def add(self, shape):
    self.__shapes.append(shape)

def area(self):
    return sum(s.area() for s in self.__shapes)

def perimeter(self):
    return sum(s.perimeter() for s in self.__shapes)

def contains(self, x, y):
    return any(s.contains(x,y) for s in self.__shapes)

def boundary_points(self, n=32):
    pts = []
    for s in self.__shapes:
        pts.extend(s.boundary_points(n))
    return pts

def paint(self, canvas):
    for s in self.__shapes:
        s.paint(canvas)
```

if **name** == "**main**":
c = Canvas(500,500)

```
r = Rectangle(150,100,50,50)
circ = Circle(60,300,150)
t = Triangle(120,130,140,200,300)

group = CompoundShape()
group.add(r)
group.add(circ)
group.add(t)

group.paint(c)
c.show()
```
# Out:
#   Cell In[9], line 5
#     def **init**(self, width=400, height=400):
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# 11. Create a `RasterDrawing` class. Demonstrate that you can create a drawing made of several shapes, paint the drawing, modify the drawing, and paint it again.

# %%
from tkinter import Tk, Canvas as TkCanvas
import math

class Canvas:
    def __init__(self, width=500, height=500):
        self.root = Tk()
        self.canvas = TkCanvas(self.root, width=width, height=height)
        self.canvas.pack()
    def draw_polygon(self, pts, color="black"):
        flat = [coord for p in pts for coord in p]
        self.canvas.create_polygon(flat, outline=color, fill="")
    def draw_oval(self, x0,y0,x1,y1,color="black"):
        self.canvas.create_oval(x0,y0,x1,y1,outline=color)
    def show(self): self.root.mainloop()
    def clear(self): self.canvas.delete("all")

class Shape:
    def area(self): raise NotImplementedError
    def perimeter(self): raise NotImplementedError
    def contains(self,x,y): raise NotImplementedError
    def boundary_points(self,n=32): raise NotImplementedError
    def paint(self,canvas): raise NotImplementedError
    def overlaps(self,other):
        return any(other.contains(x,y) for x,y in self.boundary_points()) or \
               any(self.contains(x,y) for x,y in other.boundary_points())

class Rectangle(Shape):
    def __init__(self,l,w,x,y): self.__length=l; self.__width=w; self.__x=x; self.__y=y
    def area(self): return self.__length*self.__width
    def perimeter(self): return 2*(self.__length+self.__width)
    def contains(self,x,y): return self.__x<=x<=self.__x+self.__length and self.__y<=y<=self.__y+self.__width
    def boundary_points(self,n=32):
        pts=[]; L,W=self.__length,self.__width; X,Y=self.__x,self.__y
        for i in range(n):
            t=i/n
            if t<0.25: px=X+t*4*L; py=Y
            elif t<0.5: px=X+L; py=Y+(t-0.25)*4*W
            elif t<0.75: px=X+L-(t-0.5)*4*L; py=Y+W
            else: px=X; py=Y+W-(t-0.75)*4*W
            pts.append((px,py))
        return pts
    def paint(self,canvas): canvas.draw_polygon([(self.__x,self.__y),(self.__x+self.__length,self.__y),(self.__x+self.__length,self.__y+self.__width),(self.__x,self.__y+self.__width)])

class Circle(Shape):
    def __init__(self,r,x,y): self.__radius=r; self.__x=x; self.__y=y
    def area(self): return math.pi*self.__radius**2
    def perimeter(self): return 2*math.pi*self.__radius
    def contains(self,x,y): return (x-self.__x)**2+(y-self.__y)**2<=self.__radius**2
    def boundary_points(self,n=32): return [(self.__x+self.__radius*math.cos(2*math.pi*i/n),self.__y+self.__radius*math.sin(2*math.pi*i/n)) for i in range(n)]
    def paint(self,canvas): r=self.__radius; canvas.draw_oval(self.__x-r,self.__y-r,self.__x+r,self.__y+r)

class Triangle(Shape):
    def __init__(self,a,b,c,x,y):
        self.__a=a; self.__b=b; self.__c=c
        self.__p1=(x,y); self.__p2=(x+a,y)
        cosC=(a*a+b*b-c*c)/(2*a*b); sinC=math.sqrt(1-cosC**2)
        self.__p3=(x+b*cosC,y+b*sinC)
    def area(self): s=(self.__a+self.__b+self.__c)/2; return math.sqrt(s*(s-self.__a)*(s-self.__b)*(s-self.__c))
    def perimeter(self): return self.__a+self.__b+self.__c
    def contains(self,x,y):
        def A(x1,y1,x2,y2,x3,y3): return abs((x1*(y2-y3)+x2*(y3-y1)+x3*(y1-y2))/2)
        a=A(*self.__p1,*self.__p2,*self.__p3); a1=A(x,y,*self.__p2,*self.__p3); a2=A(*self.__p1,x,y,*self.__p3); a3=A(*self.__p1,*self.__p2,x,y)
        return abs(a-(a1+a2+a3))<1e-6
    def boundary_points(self,n=32):
        verts=[self.__p1,self.__p2,self.__p3]; pts=[]
        for i in range(n):
            t=i/n*3; e=int(t); l=t-e
            x=verts[e][0]+l*(verts[(e+1)%3][0]-verts[e][0])
            y=verts[e][1]+l*(verts[(e+1)%3][1]-verts[e][1])
            pts.append((x,y))
        return pts
    def paint(self,canvas): canvas.draw_polygon([self.__p1,self.__p2,self.__p3])

class RasterDrawing:
    def __init__(self):
        self.shapes=[]
    def add(self,s): self.shapes.append(s)
    def remove(self,s): self.shapes.remove(s)
    def paint(self,canvas):
        canvas.clear()
        for s in self.shapes: s.paint(canvas)

if __name__=="__main__":
    c=Canvas()
    r=Rectangle(100,80,50,50)
    circ=Circle(50,200,100)
    t=Triangle(80,90,100,150,200)
    drawing=RasterDrawing()
    drawing.add(r); drawing.add(circ); drawing.add(t)
    drawing.paint(c)  # paint first
    r2=Rectangle(60,40,300,50)
    drawing.add(r2)
    drawing.paint(c)  # paint again with added shape
    c.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 from tkinter import Tk, Canvas as TkCanvas
#       2 import math
#       4 class Canvas:
#
# ModuleNotFoundError: No module named 'tkinter'

# %% [markdown]
# 12. Implement the ability to load/save raster drawings and demonstate that your method works. One way to implement this ability:
#
#    * Overload `__repr__` functions of all objects to return strings of the python code that would construct the object.
#
#    * In the save method of raster drawing class, store the representations into the file.
#    * Write a loader function that reads the file and uses `eval` to instantiate the object.
#
# For example:

# %%
class foo:
    def __init__(self,a,b=None):
        self.a=a
        self.b=b
        
    def __repr__(self):
        return "foo("+repr(self.a)+","+repr(self.b)+")"
    
    def save(self,filename):
        f=open(filename,"w")
        f.write(self.__repr__())
        f.close()
        
   
def foo_loader(filename):
    f=open(filename,"r")
    tmp=eval(f.read())
    f.close()
    return tmp

# %%
# Test
print(repr(foo(1,"hello")))
# Out:
# foo(1,'hello')

# %%
# Create an object and save it
def foo_loader(filename):
    with open(filename, "r") as f:
        obj = eval(f.read())
    return obj

loaded_ff = foo_loader("Test.foo")
print(loaded_ff.a, loaded_ff.b)  # Outputs: 1 hello
ff=foo(1,"hello")
ff.save("Test.foo")
# Out:
# 1 hello

# %%
# Check contents of the saved file
# !cat Test.foo
# Out:
# foo(1,'hello')

# %%
# Load the object
ff_reloaded=foo_loader("Test.foo")
ff_reloaded
# Out:
# foo(1,'hello')
